# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # Processing 1: Unpacking Features of Interest & Patterns

# %%
playlist1 = pd.read_csv('PLAYLIST DATA FOR PID=2AdB4xiE5SGYj2qoRTfWLz')
playlist2 = pd.read_csv('PLAYLIST DATA FOR PID=2NtE3gBa5ASlxkAKbfhOlr')
playlist3 = pd.read_csv('PLAYLIST DATA FOR PID=3W1IB3Xzff33bujvhOHQHp')
playlist4 = pd.read_csv('PLAYLIST DATA FOR PID=3ycbGxN9b34eoi0uPuOV2X')
playlist5 = pd.read_csv('PLAYLIST DATA FOR PID=4ORd4FzkfMmloJauXvIHud')
playlist6 = pd.read_csv('PLAYLIST DATA FOR PID=4erXDkn5Uy78z2w5KUmPdM')
playlist7 = pd.read_csv('PLAYLIST DATA FOR PID=6XcRSnrvQjPAZ91V8zzY4Y')
playlist8 = pd.read_csv('PLAYLIST DATA FOR PID=6aBcf0i0ySavARDzwSZWub')
playlists = [playlist1, playlist2, playlist3, playlist4, playlist5, playlist6,playlist7, playlist8]
[playlist.shape for playlist in playlists]
# Out:
# [(61, 19),
#  (100, 19),
#  (97, 19),
#  (32, 19),
#  (40, 19),
#  (67, 19),
#  (34, 19),
#  (41, 19)]

# %%
playlist1.head()
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.694   0.594   11    -5.362     0       0.0358
# 1           1         0.766   0.522    0    -6.713     1       0.2990
# 2           2         0.875   0.359    7   -11.823     1       0.1430
# 3           3         0.696   0.603    0    -7.140     1       0.1380
# 4           4         0.648   0.481   11    -9.786     1       0.0870
#
#    acousticness  instrumentalness  liveness  valence    tempo            type  \
# 0         0.453          0.000003    0.0548    0.677   89.996  audio_features
# 1         0.424          0.000000    0.4590    0.373  120.011  audio_features
# 2         0.227          0.264000    0.1050    0.574  100.043  audio_features
# 3         0.556          0.005740    0.3340    0.493  109.066  audio_features
# 4         0.608          0.002370    0.0967    0.271  149.980  audio_features
#
#                        id                                   uri  \
# ...
